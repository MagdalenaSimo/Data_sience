# %%
import pandas as pd
import numpy as np

# Settings
pd.options.display.max_rows = 9999
pd.options.display.max_columns = 9999

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

mall_tab = pd.read_csv('Mall_Customers.csv')
mall_tab
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
#is null in tab?
mall_tab.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#seaching name of columns
mall_tab.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
#How is age average our clients?
age = mall_tab['Age'].median()
age
# Out:
# 36.0

# %%
# #How old are you our clients?
age = mall_tab['Age']
age.plot(y=age, kind='hist', bins=20, grid=True, figsize=(12,6));

# %%
#How many female and male shopping in mall?
mall_tab['Gender'].value_counts().to_frame().head(2)
# Out:
#         Gender
# Female     112
# Male        88

# %%
# How many percent is female and male?
gender = mall_tab['Gender'].value_counts()
gender.plot(kind='pie', labeldistance=1.1, autopct='%1.0f%%', pctdistance=0.7, shadow=True, startangle=140, figsize=(12, 8))

# %%
mall_tab.pivot_table(index='Age', columns='Gender', values=['Annual Income (k$)',	'Spending Score (1-100)'], aggfunc=np.mean)
# Out:
#        Annual Income (k$)             Spending Score (1-100)
# Gender             Female        Male                 Female       Male
# Age
# 18              65.000000   46.666667              48.000000  64.000000
# 19              64.000000   54.666667              52.000000  35.666667
# 20              26.500000   51.666667              40.500000  40.000000
# 21              44.750000   15.000000              63.250000  81.000000
# 22              37.000000   20.000000              65.500000  79.000000
# 23              41.500000         NaN              63.333333        NaN
# 24              29.500000   49.000000              71.000000  72.000000
# 25              72.000000   50.500000              34.000000  42.500000
# 26                    NaN   58.000000                    NaN  54.500000
# 27              56.000000   77.500000              59.250000  62.500000
# 28              76.000000   88.333333              40.000000  80.000000
# ...

# %%
#how is annunal income?
series = mall_tab['Annual Income (k$)']
series.plot(y=series, kind='hist', bins=20, grid=True, figsize=(12,6));

# %%
#average annual income
x = mall_tab['Annual Income (k$)'].median()
x
# Out:
# 61.5

# %%
#min values
z = mall_tab['Annual Income (k$)'].min()
z
# Out:
# 15

# %%
#max values
n = mall_tab['Spending Score (1-100)'].max()
n
# Out:
# 99

# %%
#min values
z = mall_tab['Spending Score (1-100)'].min()
z
# Out:
# 1

# %%
#How is the greatest Spending score?
series2 = mall_tab['Spending Score (1-100)']
series2.plot(y=series, kind='hist', bins=20, grid=True, figsize=(12,6));
